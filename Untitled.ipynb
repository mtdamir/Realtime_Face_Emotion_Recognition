# %%
import cv2 
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('happy.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.71it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 3.54114317843451e-07,
#    'disgust': 6.830057826308182e-14,
#    'fear': 2.8516490655566975e-06,
#    'happy': 99.93596673775116,
#    'sad': 2.1874517365507253e-07,
#    'surprise': 0.0012630166879297364,
#    'neutral': 0.06276007459192579},
#   'dominant_emotion': 'happy',
#   'region': {'x': 202, 'y': 129, 'w': 180, 'h': 180},
#   'face_confidence': 6.693222050962504,
#   'age': 36,
#   'gender': {'Woman': 4.819284379482269, 'Man': 95.18072009086609},
#   'dominant_gender': 'Man',
#   'race': {'asian': 22.32499601542997,
#    'indian': 12.064632080241195,
#    'black': 37.02822482249441,
#    'white': 3.628306030833002,
#    'middle eastern': 3.267996368647055,
#    'latino hispanic': 21.685837604303646},
#   'dominant_race': 'black'}]

# %%
type(predictions)
# Out:
# list

# %%
import json
predictions1 = {
    "emotion": {
        "angry": 3.54114317843451e-07,
        "disgust": 6.830057826308182e-14,
        "fear": 2.8516490655566975e-06,
        "happy": 99.93596673775116,
        "sad": 2.1874517365507253e-07,
        "surprise": 0.0012630166879297364,
        "neutral": 0.06276007459192579
    },
    "dominant_emotion": "happy",
    "region": {
        "x": 202,
        "y": 129,
        "w": 180,
        "h": 180
    },
    "face_confidence": 6.693222050962504,
    "age": 36,
    "gender": {
        "Woman": 4.819284379482269,
        "Man": 95.18072009086609
    },
    "dominant_gender": "Man",
    "race": {
        "asian": 22.32499601542997,
        "indian": 12.064632080241195,
        "black": 37.02822482249441,
        "white": 3.628306030833002,
        "middle eastern": 3.267996368647055,
        "latino hispanic": 21.685837604303646
    },
    "dominant_race": "black"
}

print(predictions1)
# Out:
# {'emotion': {'angry': 3.54114317843451e-07, 'disgust': 6.830057826308182e-14, 'fear': 2.8516490655566975e-06, 'happy': 99.93596673775116, 'sad': 2.1874517365507253e-07, 'surprise': 0.0012630166879297364, 'neutral': 0.06276007459192579}, 'dominant_emotion': 'happy', 'region': {'x': 202, 'y': 129, 'w': 180, 'h': 180}, 'face_confidence': 6.693222050962504, 'age': 36, 'gender': {'Woman': 4.819284379482269, 'Man': 95.18072009086609}, 'dominant_gender': 'Man', 'race': {'asian': 22.32499601542997, 'indian': 12.064632080241195, 'black': 37.02822482249441, 'white': 3.628306030833002, 'middle eastern': 3.267996368647055, 'latino hispanic': 21.685837604303646}, 'dominant_race': 'black'}

# %%
type(predictions1)
# Out:
# dict

# %%
predictions1['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.4,4)

for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y),(x+w, y+h), (0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            predictions1['dominant_emotion'],
            (0,100),
            font,1,
            (0,0,255),
            2,
            cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad4.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.51it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.3650906030088663,
#    'disgust': 0.018648753757588565,
#    'fear': 4.4791534543037415,
#    'happy': 0.0017115758964791894,
#    'sad': 76.65157914161682,
#    'surprise': 0.0009840421625995077,
#    'neutral': 18.482832610607147},
#   'dominant_emotion': 'sad',
#   'region': {'x': 42, 'y': 61, 'w': 183, 'h': 183},
#   'face_confidence': 10.559015124454163,
#   'age': 25,
#   'gender': {'Woman': 95.20694613456726, 'Man': 4.793047904968262},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 4.942545806742932e-06,
#    'indian': 2.85941313629928e-06,
#    'black': 1.806016662797075e-08,
#    'white': 99.96504783213709,
#    'middle eastern': 0.013950854398505168,
#    'latino hispanic': 0.020994465332284162},
#   'dominant_race': 'white'}]

# %%
import json
predictions1 = {
    "emotion": {
      "angry": 0.3650906030088663,
      "disgust": 0.018648753757588565,
      "fear": 4.4791534543037415,
      "happy": 0.0017115758964791894,
      "sad": 76.65157914161682,
      "surprise": 0.0009840421625995077,
      "neutral": 18.482832610607147
    },
    "dominant_emotion": "sad",
    "region": {
      "x": 42,
      "y": 61,
      "w": 183,
      "h": 183
    },
    "face_confidence": 10.559015124454163,
    "age": 25,
    "gender": {
      "Woman": 95.20694613456726,
      "Man": 4.793047904968262
    },
    "dominant_gender": "Woman",
    "race": {
      "asian": 4.942545806742932e-06,
      "indian": 2.85941313629928e-06,
      "black": 1.806016662797075e-08,
      "white": 99.96504783213709,
      "middle eastern": 0.013950854398505168,
      "latino hispanic": 0.020994465332284162
    },
    "dominant_race": "white"
  }

# %%
type(predictions1)
# Out:
# dict

# %%
# real time vide  demo for face  emotion recognition
import cv2 
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("can not open")
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame, actions = ['emotion'])

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1,4)

    for(x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y),(x+w, y+h), (0,255,0),2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    cv2.putText(frame,
            result['dominant_emotion'],
            (50,50),
            font,3,
            (0,0,255),
            2,
            cv2.LINE_4)
    cv2.imshow('Demo video',frame)

    if  cv2.waitKey(2) & 0xff == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@8382.066] global cap_v4l.cpp:997 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ERROR:0@8382.067] global obsensor_uvc_stream_channel.cpp:159 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 26
#      20     cv2.rectangle(frame, (x,y),(x+w, y+h), (0,255,0),2)
#      22 font = cv2.FONT_HERSHEY_SIMPLEX
#      24 cv2.putText(frame,
#      25         type(result),
# ---> 26         result['dominant_emotion'],
#      27         (50,50),
#      28         font,3,
#      29         (0,0,255),
#      30         2,
#      31         cv2.LINE_4)
#      32 cv2.imshow('Demo video',frame)
#      34 if  cv2.waitKey(2) & 0xff == ord('q'):
#
# TypeError: list indices must be integers or slices, not str
